# %% [markdown]
# # Check for cic's that sent stats to S3 but are not linked to an ordernumber.
# These cic's are potentially accidentally removed from our cloud during refurbishing of a batch of cics.

# %%
import mysql.connector
from mysql.connector import Error
from urllib.parse import urlparse
from dotenv import load_dotenv
import os
from pathlib import Path
import json
import redis
import pandas as pd # only if needed for filtering of data

# %%
# load .env file
env_path = Path('../') / '.env'
load_dotenv(env_path)

REDIS_URL = os.getenv("REDISPROD")
MYSQL_URL = os.getenv('MYSQLPROD')

# %%
def get_cic_stats_from_redis(redis_url):
    # Connect to Redis database
    parsed_url = urlparse(redis_url)
    r = redis.Redis(host=parsed_url.hostname,
                    port=parsed_url.port,
                    db=0,
                    password=parsed_url.password,
                    username=parsed_url.username)
    
    # get objects from redis
    redis_objects = r.mget(r.keys(pattern="cic:*CIC*lastStat*"))
    results = []
    for obj in redis_objects:
        try:
            results.append(json.loads(obj.decode()))
        except:
            pass
    return results

# %%
# get data from mysql
parsed_mysql_url = urlparse(MYSQL_URL)

try:
    connection = mysql.connector.connect(host=parsed_mysql_url.hostname,
                                         user=parsed_mysql_url.username,
                                         password=parsed_mysql_url.password,
                                         database=parsed_mysql_url.path[1:],
                                         port=parsed_mysql_url.port)
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("SELECT * FROM cic WHERE orderNumber is NULL;")
        fields = [field_md[0] for field_md in cursor.description]
        result = [dict(zip(fields,row)) for row in cursor.fetchall()]
        df_mysql = pd.DataFrame(result)
except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed")
# Out:
# Connected to MySQL Server version  8.0.28
# MySQL connection is closed

# %%
# get cic data from redis
redis_data = get_cic_stats_from_redis(REDIS_URL)

df_redis = pd.json_normalize(redis_data)

# %%
df_mysql
# Out:
#                                             id               createdAt  \
# 0     CIC-002fd9e7-4ec3-5ba0-9887-8200ac406ae9 2023-07-27 04:44:46.780
# 1     CIC-00397c56-d471-5a15-a964-56191a52c44f 2023-03-20 08:46:33.360
# 2     CIC-0056683f-8a2f-5fe0-bb22-d8441ffa81f5 2023-07-27 17:17:31.450
# 3     CIC-005e12d2-099f-5168-a84a-6ddb6bb369c3 2023-01-11 13:21:27.074
# 4     CIC-006b95f2-4bd3-5f5d-acab-8bedc3bdfbff 2023-07-25 01:40:13.754
# ...                                        ...                     ...
# 1528  CIC-ff9be4e4-38c8-59bd-a8eb-2eeee2922631 2023-07-21 05:40:19.162
# 1529  CIC-ffb65bfc-aa61-5b67-aee9-e31e71b63daa 2023-07-25 06:22:27.855
# 1530  CIC-ffda3016-6776-50e0-9e34-da189ee90622 2023-07-20 12:28:03.665
# 1531                                 localtest 2022-11-04 10:52:08.856
# 1532                                     tppg2 2022-11-10 13:02:49.884
#
#                    updatedAt addressNumber addressStreet  \
# 0    2023-07-27 04:44:47.562          None          None
# 1    2023-04-01 11:08:14.036          None          None
# 2    2023-07-27 17:17:32.252          None          None
# 3    2023-01-26 12:14:20.457          None          None
# 4    2023-07-25 01:40:14.601          None          None
# ...                      ...           ...           ...
# 1528 2023-07-21 05:40:20.056          None          None
# 1529 2023-07-25 06:22:28.495          None          None
# 1530 2023-07-31 07:42:27.601          None          None
# 1531 2022-11-04 15:46:18.580          None          None
# 1532 2022-11-11 10:42:13.746          None          None
#
#      availableWifiNetworks  isScanningForWifi lastScannedForWifi updateStatus  \
# 0                     None                  0                NaT         None
# 1                     None                  0                NaT         None
# 2                     None                  0                NaT         None
# 3                     None                  0                NaT         None
# 4                     None                  0                NaT         None
# ...                    ...                ...                ...          ...
# 1528                  None                  0                NaT         None
# 1529                  None                  0                NaT         None
# 1530                  None                  0                NaT         None
# 1531                  None                  0                NaT         None
# 1532                  None                  0                NaT         None
#
#      updateUntil  ... maximumHeatingOutdoorTemperature ratedMaximumHousePower  \
# 0           None  ...                              NaN                    NaN
# 1           None  ...                              NaN                    NaN
# 2           None  ...                              NaN                    NaN
# 3           None  ...                              NaN                    NaN
# 4           None  ...                              NaN                    NaN
# ...          ...  ...                              ...                    ...
# 1528        None  ...                              NaN                    NaN
# 1529        None  ...                              NaN                    NaN
# 1530        None  ...                              NaN                    NaN
# 1531        None  ...                              NaN                    NaN
# 1532        None  ...                              NaN                    NaN
#
#      orderNumber       status lteInfo  hubspotDealId  name  \
# 0           None       active      {}           None  None
# 1           None       active      {}           None  None
# 2           None       active      {}           None  None
# 3           None       active      {}           None  None
# 4           None       active      {}           None  None
# ...          ...          ...     ...            ...   ...
# 1528        None       active      {}           None  None
# 1529        None       active      {}           None  None
# 1530        None       active      {}           None  None
# 1531        None  registering      {}           None  None
# 1532        None       active      {}           None  None
#
#      usePricingToLimitHeatPump installationId numberOfHeatPumps
# 0                            1         1811.0               NaN
# 1                            1            NaN               NaN
# 2                            1         1872.0               NaN
# 3                            1            NaN               NaN
# 4                            1         1549.0               NaN
# ...                        ...            ...               ...
# 1528                         1         1149.0               NaN
# 1529                         1         1576.0               NaN
# 1530                         1         1066.0               NaN
# 1531                         1            NaN               NaN
# 1532                         1            NaN               NaN
#
# [1533 rows x 32 columns]

# %%
# find ids that are in redis but not in mysql
mysql_ids = df_mysql['id'].tolist()
df_redis[(df_redis['system.quattId'].isin(mysql_ids))][['system.quattId', 'time.tsHuman', 'qc.supervisoryControlMode']].sort_values(by='system.quattId').dropna(subset=['qc.supervisoryControlMode'])
# Out:
#                                 system.quattId              time.tsHuman  \
# 610   CIC-d2e43588-fe92-5f82-a91c-98af4b9eea2b  2023-08-01T06:55:44.616Z
# 1104  CIC-d7e946f0-eedc-5972-895b-7460a06ece1e  2023-08-01T06:55:48.897Z
#
#       qc.supervisoryControlMode
# 610                         0.0
# 1104                        0.0

# %%
df_mysql[df_mysql['id'].str.contains('d2e43')]
df_redis[df_redis['system.quattId'] == "CIC-d2e43588-fe92-5f82-a91c-98af4b9eea2b"]
# Out:
# Empty DataFrame
# Columns: [hp2, time.ts, time.tsHuman, hp1.modbusSlaveId, hp1.setMainWorkingMode, hp1.setCompressorFrequencyLevel, hp1.setCirculatingPumpRelay, hp1.setCirculatingPumpDutyCycle, hp1.waterPumpLevel, hp1.getMainWorkingMode, hp1.acInputVoltage, hp1.acInputCurrent, hp1.compressorFrequencyMax, hp1.compressorFrequency, hp1.getFanSpeedMax, hp1.getFanSpeed, hp1.getCirculatingPumpRelay, hp1.temperatureOutside, hp1.evaporatorCoilTemperature, hp1.gasDischargeTemperature, hp1.lowPressureSwitch, hp1.highPressureSwitch, hp1.waterFlowSwitch, hp1.defrostFlag, hp1.mainLineCurrentProtection, hp1.compressorPhaseCurrentProtection, hp1.ipmModuleProtection, hp1.compressorOilReturnProtection, hp1.highPressureSwitchProtection, hp1.highPressureCompressorSpeedDown, hp1.firstStartPreHeatProtection, hp1.gasDischargeTempSensorProtection, hp1.evaporatorCoilTempSensorProtection, hp1.acVoltageProtection, hp1.failureAmbientTemperature, hp1.ambientTemperatureFrequencyLimitProtection, hp1.lowPressureSwitchProtection, hp1.lowPressureCompressorSpeedDown, hp1.ambientTempSensorFailure, hp1.evaporatorCoilTempSensorFailure, hp1.gasDischargeTempSensorFailure, hp1.gasReturnTempSensorFailure, hp1.evaporatorPressureSensorFailure, hp1.condenserPressureSensorFailure, hp1.highPressureSwitchLockProtection, hp1.lowPressureSwitchLockProtection, hp1.fanFailure, hp1.evaporatingPressureLockProtection, hp1.condenserPressureLockProtection, hp1.eviPressureSensorFailure, hp1.eviInletTempSensorFailure, hp1.eviOutletTempSensorFailure, hp1.masterSlaveCommunicationFailure, hp1.controlPcbModuleCommunicationFailure, hp1.compressorPhaseCurrentFailure, hp1.compressorPhaseCurrentOverload, hp1.compressorDriverFailure, hp1.moduleVDCVoltageFailure, hp1.acCurrentFailure, hp1.eepromFailure, hp1.fanDrivePcbFailure, hp1.inletWaterTempSensorFailure, hp1.outletWaterTempSensorFailure, hp1.innerCoilTempSensorFailure, hp1.dcWaterPumpFailure, hp1.condensingTemperature, hp1.evaporatingTemperature, hp1.temperatureWaterIn, hp1.temperatureWaterOut, hp1.circulatingPumpDutyCycle, hp1.power, hp1.ratedPower, hp1.compressorFrequencyDemand, hp1.commissioningExpectedPower, hp1.evaporatorPressure, hp1.condenserPressure, hp1.bottomPlateHeaterEnable, hp1.compressorCrankcaseHeaterEnable, hp1.powerInput, hp1.electricalEnergyCounter, hp1.thermalEnergyCounter, hp1.minimumCompressorFrequency, hp1.maximumCompressorFrequency, hp1.circulatingPumpPwmFeedForward, hp1.circulatingPumpPwmFeedBack, hp1.silentModeStatus, hp1.limitedByCop, hp1.watchdogCode, hp1.inletTemperatureFiltered, hp1.outletTemperatureFiltered, hp1.ambientTemperatureFiltered, boiler.otFbFaultIndication, boiler.otFbChModeActive, boiler.otFbDhwActive, boiler.otFbFlameOn, boiler.otFbCoolingStatus, boiler.otFbCh2Mode, boiler.otFbDiagnosticServiceEvent, boiler.otFbSupplyInletTemperature, boiler.otFbSupplyOutletTemperature, ...]
# Index: []
#
# [0 rows x 381 columns]

# %%
len(df_redis)
# Out:
# 2243
